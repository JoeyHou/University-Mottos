# %%
import requests
import bs4
import pandas as pd

df_university = pd.read_csv('National_University_Ranking.csv')
base_url = 'https://en.wikipedia.org/wiki/'

# %%
num_of_fail = 0
failed_unversities = []
data_universities = []
motto_list_unversity = []

df_university = df_university.dropna(how='all')
i = 0
for string in df_university['Name/Rank']:
    i += 1
    print(i)
    school_name = string.split('\n')[0]
    school_name_str = school_name.replace(' ', '_')
    response = requests.get(base_url + school_name_str)
    html = bs4.BeautifulSoup(response.text, "lxml")
    
    # If failed
    if 'Motto' not in html.get_text():
        # Launch a search for the unversity
        new_url_head = 'https://en.wikipedia.org/w/index.php?search='
        new_url_tail = '&title=Special:Search&fulltext=1'
        str_lst = school_name.split(' ')
        for st in str_lst:
            new_url_head += st
        
        response = requests.get(new_url_head + new_url_tail)
        html = bs4.BeautifulSoup(response.text, "lxml")
        if html.find_all(class_ = 'mw-search-results'):
            for child in html.find_all(class_ = 'mw-search-results')[0].children:
                new_url = base_url + child.div.a['href'][6:]
                break
            print('break!')
        else:
            print('Failed to find motto for: ' + school_name_str)
            failed_unversities.append(school_name)
            data_universities.append([school_name, ' '])
            continue
        response = requests.get(new_url)
        html = bs4.BeautifulSoup(response.text, "lxml")
    
    # If the motto is not found again
    if 'Motto' not in html.get_text():
        print('Failed to find motto for: ' + school_name_str)
        failed_unversities.append(school_name)
        data_universities.append([school_name, ' '])
        continue
        
    # If didn't fail
    for child in html.tbody.children:
        if child.th and child.th.div and 'Motto' in child.th.div.text:
            if child.td.text:
                motto = child.td.text
                data_universities.append([school_name, motto])
                motto_list_unversity.append(motto)
                print(motto)
                
df_university = pd.DataFrame(data_universities ,columns=['University','Moto'],dtype=str)
df_university.to_csv('University_mottos.csv')
# Out:
# 1
# Under God's Power She Flourishes[1]
# 2
# Truth
# 3
# In Thy light shall we see light[3] (Psalms 36:9)
# 4
# Mind and Hand[1]
# 5
# Let knowledge grow from more to more; and so be human life enriched[1]
# 6
# Light and truth
# 7
# The wind of freedom blows[1]
# 8
# Knowledge and Faith[2]
# 9
# Laws without morals are useless
# 10
# The Truth Shall Set You Free
# 11
# "Whatsoever things are true" (Philippians 4:8 AV)"The word full of grace and truth" (Gospel of John 1:14)
# 12
# 13
# A voice crying out in the wilderness[1]
# 14
# In God We Hope[1]
# 15
# Failed to find motto for: Vanderbilt_University
# 16
# Failed to find motto for: Cornell_University
# 17
# 18
# Life, Sweetness, Hope[2]
# 19
# Failed to find motto for: University_of_California--Los_Angeles
# 20
# Strength through truth
# 21
# The wise heart seeks knowledge[1]
# 22
# Both into One[a]
# 23
# Let there be light
# 24
# Let whoever earns the palm bear it
# 25
# 26
# Failed to find motto for: University_of_Virginia
# 27
# Peace and Light
# 28
# Failed to find motto for: University_of_Michigan--Ann_Arbor
# 29
# For Humanity
# 30
# To persevere and to excel
# 31
# Let there be light
# 32
# Failed to find motto for: University_of_North_Carolina--Chapel_Hill
# 33
# 34
# Ever Better (also, Always Better)
# 35
# Truth even unto its innermost parts[1]
# 36
# 37
# The welfare of the state depends upon the morals of its citizens.[a 1]
# 38
# "Ever to Excel"
# 39
# Failed to find motto for: College_of_William_and_Mary
# 40
# Let there be light
# 41
# Failed to find motto for: University_of_California--San_Diego
# 42
# 43
# 44
# 45
# Not for oneself, but for one's own
# 46
# 47
# 48
# 49
# 50
# Failed to find motto for: University_of_Texas--Austin
# 51
# "God, our light" or "The divine within the universe, however manifested, is my light."[1]
# 52
# Truth, Unity, Charity
# 53
# 54
# Knowledge crowns those who seek her
# 55
# Great is the truth
# 56
# Education for Citizenship
# 57
# 58
# 59
# 60
# "The truth will make you free"
# 61
# Let there be light
# 62
# "Theory and Practice"
# 63
# God is Our Trust[3]
# 64
# Failed to find motto for: University_of_Connecticut
# 65
# Failed to find motto for: University_of_Maryland--College_Park
# 66
# 67
# Let there be light
# 68
# Failed to find motto for: Clemson_University
# 69
# Failed to find motto for: Texas_A&M_University--College_Station
# 70
# Strength, Skill, Character (Latin)
# 71
# Wisdom and Learning
# 72
# Through adversity to the stars
# 73
# Let there be light
# 74
# "By the sword we seek peace, but peace only under liberty"
# 75
# Truth and Virtue
# 76
# A common bond for all the arts
# 77
# That I May Serve
# 78
# For God and Country
# 79
# For Church, For Texas.
# 80
# 81
# 82
# 83
# Failed to find motto for: Stony_Brook_University--SUNY
# 84
# "Learning is Power" or "Education is Opportunity"
# 85
# Torah and secular knowledge
# 86
# 87
# Let there be light
# 88
# Send Forth Thy Spirit
# 89
# "Truth and Service"
# 90
# 91
# For the greater glory of God
# 92
# God and the RiverFor the greater glory of God
# 93
# Failed to find motto for: University_at_Buffalo--SUNY
# 94
# Knowledge is the light of the mind
# 95
# Failed to find motto for: University_of_Iowa
# 96
# 97
# To accomplish without being conspicuous[1]
# 98
# Let Your Light Shine[1]
# 99
# 100
# Traditional: For City and UniversityCurrent motto: Change the World From Here
# 101
# For studies and other honest pursuits
# 102
# 103
# 104
# 105
# The Mind Moves Mountains / (lit.) Mind moves the mass

# %%
df_university
# Out:
#                                    University  \
# 0                        Princeton University
# 1                          Harvard University
# 2                         Columbia University
# 3       Massachusetts Institute of Technology
# 4                       University of Chicago
# 5                             Yale University
# 6                         Stanford University
# 7                             Duke University
# 8                  University of Pennsylvania
# 9                    Johns Hopkins University
# 10                    Northwestern University
# 11                          Dartmouth College
# 12                           Brown University
# 13                      Vanderbilt University
# 14                         Cornell University
# 15                   University of Notre Dame
# 16      University of California--Los Angeles
# 17         Washington University in St. Louis
# 18                           Emory University
# 19                      Georgetown University
# 20         University of California--Berkeley
# 21          University of Southern California
# 22                     University of Virginia
# 23                           Tufts University
# 24          University of Michigan--Ann Arbor
# 25                     Wake Forest University
# 26                        New York University
# 27    University of California--Santa Barbara
# 28  University of North Carolina--Chapel Hill
# 29                    University of Rochester
# ..                                        ...
# 48       University of Maryland--College Park
# 49                           Clark University
# 50                         Clemson University
# 51      Texas A&M University--College Station
# 52                   Florida State University
# 53                         Fordham University
# 54            Stevens Institute of Technology
# 55       University of California--Santa Cruz
# 56       University of Massachusetts--Amherst
# 57                   University of Pittsburgh
# 58       University of Minnesota--Twin Cities
# 59                              Virginia Tech
# 60                        American University
# 61                          Baylor University
# 62               Stony Brook University--SUNY
# 63                 Texas Christian University
# 64                         Yeshiva University
# 65        University of California--Riverside
# 66                    University of San Diego
# 67                          Howard University
# 68                  Loyola University Chicago
# 69                       Marquette University
# 70                University at Buffalo--SUNY
# 71                     University of Delaware
# 72                         University of Iowa
# 73                   Miami University--Oxford
# 74            University of Colorado--Boulder
# 75                University of San Francisco
# 76                      University of Vermont
# 77                       University of Oregon
#
#                                                  Moto
# 0                 Under God's Power She Flourishes[1]
# 1                                               Truth
# 2    In Thy light shall we see light[3] (Psalms 36:9)
# 3                                    Mind and Hand[1]
# 4   Let knowledge grow from more to more; and so b...
# 5                                     Light and truth
# 6                        The wind of freedom blows[1]
# 7                              Knowledge and Faith[2]
# 8                     Laws without morals are useless
# 9                        The Truth Shall Set You Free
# 10  "Whatsoever things are true" (Philippians 4:8 ...
# 11            A voice crying out in the wilderness[1]
# 12                                  In God We Hope[1]
# 13
# 14
# 15                           Life, Sweetness, Hope[2]
# 16
# 17                             Strength through truth
# 18                  The wise heart seeks knowledge[1]
# 19                                   Both into One[a]
# 20                                 Let there be light
# 21                 Let whoever earns the palm bear it
# 22
# 23                                    Peace and Light
# 24
# 25                                       For Humanity
# 26                          To persevere and to excel
# 27                                 Let there be light
# 28
# 29                  Ever Better (also, Always Better)
# ..                                                ...
# 48
# 49                                 Let there be light
# 50
# 51
# 52                 Strength, Skill, Character (Latin)
# 53                                Wisdom and Learning
# 54                     Through adversity to the stars
# 55                                 Let there be light
# 56  "By the sword we seek peace, but peace only un...
# 57                                   Truth and Virtue
# 58                     A common bond for all the arts
# 59                                   That I May Serve
# 60                                For God and Country
# 61                             For Church, For Texas.
# 62
# 63  "Learning is Power" or "Education is Opportunity"
# 64                        Torah and secular knowledge
# 65                                 Let there be light
# 66                              Send Forth Thy Spirit
# 67                                "Truth and Service"
# 68                       For the greater glory of God
# 69      God and the RiverFor the greater glory of God
# 70
# 71                 Knowledge is the light of the mind
# 72
# 73         To accomplish without being conspicuous[1]
# 74                            Let Your Light Shine[1]
# 75  Traditional: For City and UniversityCurrent mo...
# 76              For studies and other honest pursuits
# 77  The Mind Moves Mountains / (lit.) Mind moves t...
#
# [78 rows x 2 columns]

# %%
words = {}
special_char = ['[', ']', ':', '(', ')', '"', '.', ',', '/', '1', '2', '3']
for indx in range(len(motto_list_unversity)):
    tmp_string = motto_list_unversity[indx]
    for char in special_char:
        if char in tmp_string:
            tmp_string = tmp_string.replace(char, '')
    for word in tmp_string.split(' '):
        word = word.lower()
        if word in words:
            words[word] += 1
        else:
            words[word] = 1

# %%
words
# Out:
# {'': 2,
#  '4': 1,
#  '48': 1,
#  '69': 1,
#  'a': 2,
#  'accomplish': 1,
#  'adversity': 1,
#  'all': 1,
#  'also': 1,
#  'always': 1,
#  'and': 16,
#  'are': 2,
#  'arts': 1,
#  'avthe': 1,
#  'be': 8,
#  'bear': 1,
#  'being': 1,
#  'better': 2,
#  'blows': 1,
#  'bond': 1,
#  'both': 1,
#  'but': 2,
#  'by': 1,
#  'change': 1,
#  'character': 1,
#  'charity': 1,
#  'church': 1,
#  'citizensa': 1,
#  'citizenship': 1,
#  'city': 1,
#  'common': 1,
#  'conspicuous': 1,
#  'country': 1,
#  'crowns': 1,
#  'crying': 1,
#  'depends': 1,
#  'divine': 1,
#  'earns': 1,
#  'education': 2,
#  'enriched': 1,
#  'even': 1,
#  'ever': 2,
#  'excel': 2,
#  'faith': 1,
#  'flourishes': 1,
#  'for': 11,
#  'forth': 1,
#  'free': 2,
#  'freedom': 1,
#  'from': 2,
#  'full': 1,
#  'glory': 2,
#  'god': 7,
#  "god's": 1,
#  'gospel': 1,
#  'grace': 1,
#  'great': 1,
#  'greater': 2,
#  'grow': 1,
#  'hand': 1,
#  'heart': 1,
#  'her': 1,
#  'here': 1,
#  'honest': 1,
#  'hope': 2,
#  'however': 1,
#  'human': 1,
#  'humanity': 1,
#  'i': 1,
#  'in': 3,
#  'innermost': 1,
#  'into': 1,
#  'is': 6,
#  'it': 1,
#  'its': 2,
#  'john': 1,
#  'knowledge': 6,
#  'latin': 1,
#  'laws': 1,
#  'learning': 2,
#  'let': 10,
#  'liberty': 1,
#  'life': 2,
#  'light': 15,
#  'lit': 1,
#  'make': 1,
#  'manifested': 1,
#  'mass': 1,
#  'may': 1,
#  'mind': 4,
#  'morals': 2,
#  'more': 1,
#  'more;': 1,
#  'motto': 1,
#  'mountains': 1,
#  'moves': 2,
#  'my': 1,
#  'not': 1,
#  'of': 8,
#  "one's": 1,
#  'onea': 1,
#  'oneself': 1,
#  'only': 1,
#  'opportunity': 1,
#  'or': 2,
#  'other': 1,
#  'our': 2,
#  'out': 1,
#  'own': 1,
#  'palm': 1,
#  'parts': 1,
#  'peace': 3,
#  'persevere': 1,
#  'philippians': 1,
#  'power': 2,
#  'practice': 1,
#  'psalms': 1,
#  'pursuits': 1,
#  'riverfor': 1,
#  'secular': 1,
#  'see': 1,
#  'seek': 2,
#  'seeks': 1,
#  'send': 1,
#  'serve': 1,
#  'service': 1,
#  'set': 1,
#  'shall': 2,
#  'she': 1,
#  'shine': 1,
#  'skill': 1,
#  'so': 1,
#  'spirit': 1,
#  'stars': 1,
#  'state': 1,
#  'strength': 2,
#  'studies': 1,
#  'sweetness': 1,
#  'sword': 1,
#  'texas': 1,
#  'that': 1,
#  'the': 23,
#  'theory': 1,
#  'there': 7,
#  'things': 1,
#  'those': 1,
#  'through': 2,
#  'thy': 2,
#  'to': 6,
#  'torah': 1,
#  'traditional': 1,
#  'true': 1,
#  'trust': 1,
#  'truth': 11,
#  'under': 2,
#  'unity': 1,
#  'universe': 1,
#  'universitycurrent': 1,
#  'unto': 1,
#  'upon': 1,
#  'useless': 1,
#  'virtue': 1,
#  'voice': 1,
#  'we': 3,
#  'welfare': 1,
#  'whatsoever': 1,
#  'who': 1,
#  'whoever': 1,
#  'wilderness': 1,
#  'will': 1,
#  'wind': 1,
#  'wisdom': 1,
#  'wise': 1,
#  'within': 1,
#  'without': 2,
#  'word': 1,
#  'world': 1,
#  'you': 2,
#  'your': 1}

# %%
df_university
# Out:
#                                  University  \
# 0                      Princeton University
# 1                        Harvard University
# 2                       Columbia University
# 3     Massachusetts Institute of Technology
# 4                     University of Chicago
# 5                           Yale University
# 6                       Stanford University
# 7                           Duke University
# 8                University of Pennsylvania
# 9                  Johns Hopkins University
# 10                  Northwestern University
# 11                        Dartmouth College
# 12                         Brown University
# 13                 University of Notre Dame
# 14       Washington University in St. Louis
# 15                         Emory University
# 16                    Georgetown University
# 17       University of California--Berkeley
# 18        University of Southern California
# 19                         Tufts University
# 20                   Wake Forest University
# 21                      New York University
# 22  University of California--Santa Barbara
# 23                  University of Rochester
# 24                      Brandeis University
# 25                    University of Florida
# 26                           Boston College
# 27          University of California--Davis
# 28                        Tulane University
# 29         University of Wisconsin--Madison
# ..                                      ...
# 32                      University of Miami
# 33          Ohio State University--Columbus
# 34            Southern Methodist University
# 35                 University of Washington
# 36          Worcester Polytechnic Institute
# 37             George Washington University
# 38                         Clark University
# 39                 Florida State University
# 40                       Fordham University
# 41          Stevens Institute of Technology
# 42     University of California--Santa Cruz
# 43     University of Massachusetts--Amherst
# 44                 University of Pittsburgh
# 45     University of Minnesota--Twin Cities
# 46                            Virginia Tech
# 47                      American University
# 48                        Baylor University
# 49               Texas Christian University
# 50                       Yeshiva University
# 51      University of California--Riverside
# 52                  University of San Diego
# 53                        Howard University
# 54                Loyola University Chicago
# 55                     Marquette University
# 56                   University of Delaware
# 57                 Miami University--Oxford
# 58          University of Colorado--Boulder
# 59              University of San Francisco
# 60                    University of Vermont
# 61                     University of Oregon
#
#                                                  Moto
# 0                 Under God's Power She Flourishes[1]
# 1                                               Truth
# 2    In Thy light shall we see light[3] (Psalms 36:9)
# 3                                    Mind and Hand[1]
# 4   Let knowledge grow from more to more; and so b...
# 5                                     Light and truth
# 6                        The wind of freedom blows[1]
# 7                              Knowledge and Faith[2]
# 8                     Laws without morals are useless
# 9                        The Truth Shall Set You Free
# 10  "Whatsoever things are true" (Philippians 4:8 ...
# 11            A voice crying out in the wilderness[1]
# 12                                  In God We Hope[1]
# 13                           Life, Sweetness, Hope[2]
# 14                             Strength through truth
# 15                  The wise heart seeks knowledge[1]
# 16                                   Both into One[a]
# 17                                 Let there be light
# 18                 Let whoever earns the palm bear it
# 19                                    Peace and Light
# 20                                       For Humanity
# 21                          To persevere and to excel
# 22                                 Let there be light
# 23                  Ever Better (also, Always Better)
# 24             Truth even unto its innermost parts[1]
# 25  The welfare of the state depends upon the mora...
# 26                                    "Ever to Excel"
# 27                                 Let there be light
# 28                 Not for oneself, but for one's own
# 29  "God, our light" or "The divine within the uni...
# ..                                                ...
# 32                                 Great is the truth
# 33                          Education for Citizenship
# 34                     "The truth will make you free"
# 35                                 Let there be light
# 36                              "Theory and Practice"
# 37                                God is Our Trust[3]
# 38                                 Let there be light
# 39                 Strength, Skill, Character (Latin)
# 40                                Wisdom and Learning
# 41                     Through adversity to the stars
# 42                                 Let there be light
# 43  "By the sword we seek peace, but peace only un...
# 44                                   Truth and Virtue
# 45                     A common bond for all the arts
# 46                                   That I May Serve
# 47                                For God and Country
# 48                             For Church, For Texas.
# 49  "Learning is Power" or "Education is Opportunity"
# 50                        Torah and secular knowledge
# 51                                 Let there be light
# 52                              Send Forth Thy Spirit
# 53                                "Truth and Service"
# 54                       For the greater glory of God
# 55      God and the RiverFor the greater glory of God
# 56                 Knowledge is the light of the mind
# 57         To accomplish without being conspicuous[1]
# 58                            Let Your Light Shine[1]
# 59  Traditional: For City and UniversityCurrent mo...
# 60              For studies and other honest pursuits
# 61  The Mind Moves Mountains / (lit.) Mind moves t...
#
# [62 rows x 2 columns]

# %%
df_lac = pd.read_csv('LAC_Ranking.csv')

df_lac = df_lac.dropna(how='all')
data_lacs = []

num_of_fail_lac = 0
failed_lac = []
for string in df_lac['Name/Rank']:
    school_name = string.split('\n')[0].replace(' ', '_')
    response = requests.get(base_url + school_name)
    html = bs4.BeautifulSoup(response.text, "lxml")
    # If failed
    if 'Motto' not in html.get_text():
        new_url_head = 'https://en.wikipedia.org/w/index.php?search='
        new_url_tail = '&title=Special:Search&fulltext=1'
        str_lst = string.split('\n')[0].split(' ')
        for st in str_lst:
            new_url_head += st
        
        response = requests.get(new_url_head + new_url_tail)
        html = bs4.BeautifulSoup(response.text, "lxml")
        if html.find_all(class_ = 'mw-search-results'):
            for child in html.find_all(class_ = 'mw-search-results')[0].children:
                new_url = base_url + child.div.a['href'][6:]
                break
        else:
            print('Failed to find motto for: ' + school_name)
            failed_lac.append(string.split('\n')[0])
            continue
        response = requests.get(new_url)
        html = bs4.BeautifulSoup(response.text, "lxml")
        
    if 'Motto' not in html.get_text():
        print('Failed to find motto for: ' + school_name)
        failed_lac.append(string.split('\n')[0])
        
    # If didn't fail
    for child in html.tbody.children:
        if child.th and child.th.div and 'Motto' in child.th.div.text:
            if child.td.text:
                motto = child.td.text
                data_lacs.append([school_name, motto])
                print('The motto of ' + string.split('\n')[0] + ' is "' + motto + '"')
                
df_lacs = pd.DataFrame(data_lacs, columns=['LAC','Moto'],dtype=str)
df_lacs.to_csv('LAC_mottos.csv')
# Out:
# The motto of Williams College is ""Through the Generosity of E. Williams, Esquire"[1]"
# The motto of Amherst College is "Let them enlighten the lands[1]"
# The motto of Wellesley College is "Not to be ministered unto, but to minister"
# The motto of Bowdoin College is "As an eagle towards the sky"
# The motto of Carleton College is "The Revelation / Announcement of Your Words Illuminates"
# The motto of Middlebury College is "Knowledge and Virtue"
# Failed to find motto for: Pomona_College
# The motto of Claremont McKenna College is "Civilization prospers with commerce[1]"
# The motto of Davidson College is "Let Learning Be Cherished Where Liberty Has Arisen"
# The motto of Grinnell College is "Truth and Humanity"
# Failed to find motto for: Vassar_College
# The motto of Washington and Lee University is ""Not Unmindful of the Future""
# The motto of Colgate University is "For God and for Truth"
# The motto of Hamilton College is "Know Thyself"
# The motto of Colby College is "Knowledge [is] the Light of the Mind"
# Failed to find motto for: Harvey_Mudd_College
# Failed to find motto for: Wesleyan_University
# The motto of Bates College is "With Ardor and Devotion by Charles Sumner"
# The motto of United States Naval Academy is "From Knowledge, Seapower"
# The motto of Barnard College is "Following the Way of Reason"
# The motto of University of Richmond is "Word of life and the light of knowledge [1]"
# The motto of Bryn Mawr College is "I Delight in the Truth"
# The motto of Macalester College is "Nature and Revelation are twin sisters of heaven"
# The motto of Kenyon College is "Valiantly bear the cross"
# The motto of College of the Holy Cross is "In this sign you shall conquer"
# Failed to find motto for: Bucknell_University
# The motto of Lafayette College is "The truth shall set you free.[1]"
# The motto of Occidental College is "The West is nearest the East"
# The motto of Union College is "Under the laws of Minerva, we all become brothers and sisters"
# Failed to find motto for: Denison_University
# The motto of Whitman College is "Through adversities I rise"
# The motto of Centre College is "Learning is the Light of the Mind"
# The motto of Connecticut College is ""Like a tree planted by rivers of water" (that bringeth forth its fruit in its season. – Psalm 1:3)"
# The motto of Trinity College is "For Church and Country"
# The motto of Gettysburg College is "Do Great Work"
# Failed to find motto for: Sewanee--University_of_the_South
